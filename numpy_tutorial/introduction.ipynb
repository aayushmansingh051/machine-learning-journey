# %%
import numpy as np

# %%
arr=np.array([1,2,3])
arr
# Out:
# array([1, 2, 3])

# %%
python_list=list(range(100))

# %%
python_list[0:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
import sys
sys.getsizeof(python_list[0])*len(python_list)
# Out:
# 2400

# %%
import numpy as np
numpy_array = np.arange(100)
print(numpy_array[:5])
# Out:
# [0 1 2 3 4]

# %%
import time
size=100000
l1=list(range(size))
l2=list(range(size))
l3=(x+y for x,y in zip(l1,l2))

# %%
import numpy as np
n1=np.arange(5)
n2=np.arange(5)
n1,n2
# Out:
# (array([0, 1, 2, 3, 4]), array([0, 1, 2, 3, 4]))

# %%
n1*n2
# Out:
# array([ 0,  1,  4,  9, 16])

# %%
rev_q1=np.array([10,12,13])
rev_q1.ndim
# Out:
# 1
