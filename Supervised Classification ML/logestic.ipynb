# %%
from sklearn.datasets import make_classification

# Create synthetic dataset
X, y = make_classification(
    n_samples=1000,      # number of rows
    n_features=10,       # number of features (columns)
    n_classes=3,         # number of target classes
    random_state=42
)

print(X.shape)  # (1000, 10)
print(y[:10])   # first 10 class labels
