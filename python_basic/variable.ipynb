# %%
can="soda"

# %%
can="beans"

# %%
can
# Out:
# 'beans'

# %%
can="Aayushman"
can
# Out:
# 'Aayushman'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 p=3
#       2 r=5
# ----> 3 t=t
#       4 si=p*r*t
#       5 print(si)
#
# NameError: name 't' is not defined

# %%
p=4
r=4
t=2
si=p*r*t
print(si)
type(si)
# Out:
# 32
# int

# %%
a=Aayushman_Singh
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a=Aayushman_Singh
#       2 print(a)
#
# NameError: name 'Aayushman_Singh' is not defined
